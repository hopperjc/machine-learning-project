# %% [markdown]
# # Preprocessing CC18 30 Menores Datasets
# Este notebook seleciona os 30 menores datasets do benchmark OpenML-CC18, faz pré-processamento (imputação, encoding, normalização) e split 70/30, salvando os resultados em arquivos .npz e .joblib.

# %%
import openml
import os
import joblib
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.model_selection import train_test_split

# Caso possua uma API key:
# openml.config.apikey = 'SUA_CHAVE_AQUI'

# %%
# Obter o benchmark suite CC18
benchmark_suite = openml.study.get_suite(suite_id='OpenML-CC18')
dataset_ids = benchmark_suite.data

# Listar metadados dos datasets
dlist = openml.datasets.list_datasets(data_id=dataset_ids, output_format='dataframe')
# Ordenar por número de instâncias
dlist_sorted = dlist.sort_values(by='NumberOfInstances')
# Selecionar 30 menores
smallest_30 = dlist_sorted.head(30)
smallest_30
# Out:
#          did                              name  version uploader  status  \
# 23381  23381                     dresses-sales        2       64  active
# 1063    1063                               kc2        1        2  active
# 6332    6332                    cylinder-bands        2        2  active
# 40994  40994  climate-model-simulation-crashes        4     4265  active
# 1510    1510                              wdbc        1       64  active
# 1480    1480                              ilpd        1       64  active
# 11        11                     balance-scale        1        1  active
# 29        29                   credit-approval        1        1  active
# 15        15                          breast-w        1        1  active
# 188      188                        eucalyptus        1        1  active
# 1464    1464  blood-transfusion-service-center        1       64  active
# 37        37                          diabetes        1        1  active
# 469      469                  analcatdata_dmft        1        2  active
# 458      458            analcatdata_authorship        1        2  active
# 54        54                           vehicle        1        1  active
# 50        50                       tic-tac-toe        1        1  active
# 307      307                             vowel        2        2  active
# 31        31                          credit-g        1        1  active
# 1494    1494                       qsar-biodeg        1       64  active
# 1468    1468                            cnae-9        1       64  active
# 40966  40966                       MiceProtein        4        2  active
# 1068    1068                               pc1        1        2  active
# 1462    1462           banknote-authentication        1       64  active
# 1049    1049                               pc4        1        2  active
# 23        23                               cmc        1        1  active
# 1050    1050                               pc3        1        2  active
# 1501    1501                           semeion        1       64  active
# 40975  40975                               car        3     4265  active
# 40982  40982                steel-plates-fault        3     4265  active
# 18        18               mfeat-morphological        1        1  active
#
#       format  MajorityClassSize  MaxNominalAttDistinctValues  \
# 23381   ARFF              290.0                         24.0
# 1063    ARFF              415.0                          2.0
# 6332    ARFF              312.0                         71.0
# 40994   ARFF              494.0                          2.0
# 1510    ARFF              357.0                          2.0
# 1480    ARFF              416.0                          2.0
# 11      ARFF              288.0                          3.0
# 29      ARFF              383.0                         14.0
# 15      ARFF              458.0                          2.0
# 188     ARFF              214.0                         27.0
# 1464    ARFF              570.0                          2.0
# 37      ARFF              500.0                          2.0
# 469     ARFF              155.0                          9.0
# 458     ARFF              317.0                          4.0
# 54      ARFF              218.0                          4.0
# 50      ARFF              626.0                          3.0
# 307     ARFF               90.0                         15.0
# 31      ARFF              700.0                         10.0
# 1494    ARFF              699.0                          2.0
# 1468    ARFF              120.0                          9.0
# 40966   ARFF              150.0                          8.0
# 1068    ARFF             1032.0                          2.0
# 1462    ARFF              762.0                          2.0
# 1049    ARFF             1280.0                          2.0
# 23      ARFF              629.0                          4.0
# 1050    ARFF             1403.0                          2.0
# 1501    ARFF              162.0                         10.0
# 40975   ARFF             1210.0                          4.0
# 40982   ARFF              673.0                          7.0
# 18      ARFF              200.0                         10.0
#
#        MinorityClassSize  NumberOfClasses  NumberOfFeatures  \
# 23381              210.0              2.0              13.0
# 1063               107.0              2.0              22.0
# 6332               228.0              2.0              40.0
# 40994               46.0              2.0              21.0
# 1510               212.0              2.0              31.0
# 1480               167.0              2.0              11.0
# 11                  49.0              3.0               5.0
# 29                 307.0              2.0              16.0
# 15                 241.0              2.0              10.0
# 188                105.0              5.0              20.0
# 1464               178.0              2.0               5.0
# 37                 268.0              2.0               9.0
# 469                123.0              6.0               5.0
# 458                 55.0              4.0              71.0
# 54                 199.0              4.0              19.0
# 50                 332.0              2.0              10.0
# 307                 90.0             11.0              13.0
# 31                 300.0              2.0              21.0
# 1494               356.0              2.0              42.0
# 1468               120.0              9.0             857.0
# 40966              105.0              8.0              82.0
# 1068                77.0              2.0              22.0
# 1462               610.0              2.0               5.0
# 1049               178.0              2.0              38.0
# 23                 333.0              3.0              10.0
# 1050               160.0              2.0              38.0
# 1501               155.0             10.0             257.0
# 40975               65.0              4.0               7.0
# 40982               55.0              7.0              28.0
# 18                 200.0             10.0               7.0
#
#        NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 23381              500.0                               401.0
# 1063               522.0                                 0.0
# 6332               540.0                               263.0
# 40994              540.0                                 0.0
# 1510               569.0                                 0.0
# 1480               583.0                                 0.0
# 11                 625.0                                 0.0
# 29                 690.0                                37.0
# 15                 699.0                                16.0
# 188                736.0                                95.0
# 1464               748.0                                 0.0
# 37                 768.0                                 0.0
# 469                797.0                                 0.0
# 458                841.0                                 0.0
# 54                 846.0                                 0.0
# 50                 958.0                                 0.0
# 307                990.0                                 0.0
# 31                1000.0                                 0.0
# 1494              1055.0                                 0.0
# 1468              1080.0                                 0.0
# 40966             1080.0                               528.0
# 1068              1109.0                                 0.0
# 1462              1372.0                                 0.0
# 1049              1458.0                                 0.0
# 23                1473.0                                 0.0
# 1050              1563.0                                 0.0
# 1501              1593.0                                 0.0
# 40975             1728.0                                 0.0
# 40982             1941.0                                 0.0
# 18                2000.0                                 0.0
#
#        NumberOfMissingValues  NumberOfNumericFeatures  \
# 23381                  835.0                      1.0
# 1063                     0.0                     21.0
# 6332                   999.0                     18.0
# 40994                    0.0                     20.0
# 1510                     0.0                     30.0
# 1480                     0.0                      9.0
# 11                       0.0                      4.0
# 29                      67.0                      6.0
# 15                      16.0                      9.0
# 188                    448.0                     14.0
# 1464                     0.0                      4.0
# 37                       0.0                      8.0
# 469                      0.0                      0.0
# 458                      0.0                     70.0
# 54                       0.0                     18.0
# 50                       0.0                      0.0
# 307                      0.0                     10.0
# 31                       0.0                      7.0
# 1494                     0.0                     41.0
# 1468                     0.0                    856.0
# 40966                 1396.0                     77.0
# 1068                     0.0                     21.0
# 1462                     0.0                      4.0
# 1049                     0.0                     37.0
# 23                       0.0                      2.0
# 1050                     0.0                     37.0
# 1501                     0.0                    256.0
# 40975                    0.0                      0.0
# 40982                    0.0                     27.0
# 18                       0.0                      6.0
#
#        NumberOfSymbolicFeatures
# 23381                      12.0
# 1063                        1.0
# 6332                       22.0
# 40994                       1.0
# 1510                        1.0
# 1480                        2.0
# 11                          1.0
# 29                         10.0
# 15                          1.0
# 188                         6.0
# 1464                        1.0
# 37                          1.0
# 469                         5.0
# 458                         1.0
# 54                          1.0
# 50                         10.0
# 307                         3.0
# 31                         14.0
# 1494                        1.0
# 1468                        1.0
# 40966                       5.0
# 1068                        1.0
# 1462                        1.0
# 1049                        1.0
# 23                          8.0
# 1050                        1.0
# 1501                        1.0
# 40975                       7.0
# 40982                       1.0
# 18                          1.0

# %%
def build_preprocessing_pipeline(X: pd.DataFrame):
    feature_names = X.columns.to_list()
    continuous_cols = X.select_dtypes(include=['int64','float64']).columns.to_list()
    categorical_cols = X.select_dtypes(include=['object','category','bool']).columns.to_list()

    numeric_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
    ])
    categorical_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),
        ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
    ])
    preprocessor = ColumnTransformer([
        ('num', numeric_pipeline, continuous_cols),
        ('cat', categorical_pipeline, categorical_cols)
    ], remainder='drop', verbose_feature_names_out=False)
    return preprocessor

# %%
# Cria pasta de saída
OUTPUT_DIR = 'data'
os.makedirs(OUTPUT_DIR, exist_ok=True)

for idx, row in smallest_30.iterrows():
    dataset_id = int(row['did'] if 'did' in row else row['data_id'])
    name = row['name'].replace(' ', '_')
    print(f"Processando dataset {dataset_id} - {name}")
    # Baixar dataset
    dataset = openml.datasets.get_dataset(dataset_id)
    X_df, y_series, categorical_mask, attr_names = dataset.get_data(dataset_format='dataframe', target=dataset.default_target_attribute)
    y = y_series.to_numpy()

    # Split 70/30 estratificado
    X_train_df, X_test_df, y_train, y_test = train_test_split(
        X_df, y, test_size=0.30, random_state=42, stratify=y
    )

    # Pré-processamento
    preprocessor = build_preprocessing_pipeline(X_train_df)
    preprocessor.fit(X_train_df)
    X_train = preprocessor.transform(X_train_df)
    X_test = preprocessor.transform(X_test_df)

    # Criar pasta específica
    folder = os.path.join(OUTPUT_DIR, f"task_{dataset_id}")
    os.makedirs(folder, exist_ok=True)
    # Salvar .npz
    npz_path = os.path.join(folder, f"dataset_{dataset_id}.npz")
    np.savez_compressed(npz_path, X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)
    # Salvar preprocessor
    joblib_path = os.path.join(folder, f"preprocessor_{dataset_id}.joblib")
    joblib.dump(preprocessor, joblib_path)
    print(f" Salvo: {npz_path}")
    print(f" Salvo: {joblib_path}")
# Out:
# Processando dataset 23381 - dresses-sales
#  Salvo: data\task_23381\dataset_23381.npz
#  Salvo: data\task_23381\preprocessor_23381.joblib
# Processando dataset 1063 - kc2
#  Salvo: data\task_1063\dataset_1063.npz
#  Salvo: data\task_1063\preprocessor_1063.joblib
# Processando dataset 6332 - cylinder-bands
#  Salvo: data\task_6332\dataset_6332.npz
#  Salvo: data\task_6332\preprocessor_6332.joblib
# Processando dataset 40994 - climate-model-simulation-crashes
#  Salvo: data\task_40994\dataset_40994.npz
#  Salvo: data\task_40994\preprocessor_40994.joblib
# Processando dataset 1510 - wdbc
#  Salvo: data\task_1510\dataset_1510.npz
#  Salvo: data\task_1510\preprocessor_1510.joblib
# Processando dataset 1480 - ilpd
#  Salvo: data\task_1480\dataset_1480.npz
#  Salvo: data\task_1480\preprocessor_1480.joblib
# Processando dataset 11 - balance-scale
#  Salvo: data\task_11\dataset_11.npz
#  Salvo: data\task_11\preprocessor_11.joblib
# Processando dataset 29 - credit-approval
#  Salvo: data\task_29\dataset_29.npz
#  Salvo: data\task_29\preprocessor_29.joblib
# Processando dataset 15 - breast-w
#  Salvo: data\task_15\dataset_15.npz
#  Salvo: data\task_15\preprocessor_15.joblib
# Processando dataset 188 - eucalyptus
#  Salvo: data\task_188\dataset_188.npz
#  Salvo: data\task_188\preprocessor_188.joblib
# Processando dataset 1464 - blood-transfusion-service-center
#  Salvo: data\task_1464\dataset_1464.npz
#  Salvo: data\task_1464\preprocessor_1464.joblib
# Processando dataset 37 - diabetes
#  Salvo: data\task_37\dataset_37.npz
#  Salvo: data\task_37\preprocessor_37.joblib
# Processando dataset 469 - analcatdata_dmft
#  Salvo: data\task_469\dataset_469.npz
#  Salvo: data\task_469\preprocessor_469.joblib
# Processando dataset 458 - analcatdata_authorship
#  Salvo: data\task_458\dataset_458.npz
#  Salvo: data\task_458\preprocessor_458.joblib
# Processando dataset 54 - vehicle
#  Salvo: data\task_54\dataset_54.npz
#  Salvo: data\task_54\preprocessor_54.joblib
# Processando dataset 50 - tic-tac-toe
#  Salvo: data\task_50\dataset_50.npz
#  Salvo: data\task_50\preprocessor_50.joblib
# Processando dataset 307 - vowel
#  Salvo: data\task_307\dataset_307.npz
#  Salvo: data\task_307\preprocessor_307.joblib
# Processando dataset 31 - credit-g
#  Salvo: data\task_31\dataset_31.npz
#  Salvo: data\task_31\preprocessor_31.joblib
# Processando dataset 1494 - qsar-biodeg
#  Salvo: data\task_1494\dataset_1494.npz
#  Salvo: data\task_1494\preprocessor_1494.joblib
# Processando dataset 1468 - cnae-9
#  Salvo: data\task_1468\dataset_1468.npz
#  Salvo: data\task_1468\preprocessor_1468.joblib
# Processando dataset 40966 - MiceProtein
#  Salvo: data\task_40966\dataset_40966.npz
#  Salvo: data\task_40966\preprocessor_40966.joblib
# Processando dataset 1068 - pc1
#  Salvo: data\task_1068\dataset_1068.npz
#  Salvo: data\task_1068\preprocessor_1068.joblib
# Processando dataset 1462 - banknote-authentication
#  Salvo: data\task_1462\dataset_1462.npz
#  Salvo: data\task_1462\preprocessor_1462.joblib
# Processando dataset 1049 - pc4
#  Salvo: data\task_1049\dataset_1049.npz
#  Salvo: data\task_1049\preprocessor_1049.joblib
# Processando dataset 23 - cmc
#  Salvo: data\task_23\dataset_23.npz
#  Salvo: data\task_23\preprocessor_23.joblib
# Processando dataset 1050 - pc3
#  Salvo: data\task_1050\dataset_1050.npz
#  Salvo: data\task_1050\preprocessor_1050.joblib
# Processando dataset 1501 - semeion
#  Salvo: data\task_1501\dataset_1501.npz
#  Salvo: data\task_1501\preprocessor_1501.joblib
# Processando dataset 40975 - car
#  Salvo: data\task_40975\dataset_40975.npz
#  Salvo: data\task_40975\preprocessor_40975.joblib
# Processando dataset 40982 - steel-plates-fault
#  Salvo: data\task_40982\dataset_40982.npz
#  Salvo: data\task_40982\preprocessor_40982.joblib
# Processando dataset 18 - mfeat-morphological
#  Salvo: data\task_18\dataset_18.npz
#  Salvo: data\task_18\preprocessor_18.joblib
