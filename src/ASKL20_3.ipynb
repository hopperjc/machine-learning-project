# %%
import time
import pandas as pd
import numpy as np
import openml
import warnings
import math
import logging

# Imports do scikit-learn e auto-sklearn
from autosklearn.experimental.askl2 import AutoSklearn2Classifier

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, accuracy_score, log_loss
# Out:
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/sklearn/utils/fixes.py:28: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version  # type: ignore

# %%
# Configurações
SEED = 42
warnings.filterwarnings("ignore", category=FutureWarning)

def carregar_base_openml(openml_id):
    """Carrega um dataset do OpenML e prepara os tipos de dados."""
    dataset = openml.datasets.get_dataset(openml_id, download_data=True, download_qualities=True, download_features_meta_data=True)
    X, y, _, _ = dataset.get_data(dataset_format="dataframe", target=dataset.default_target_attribute)
    if isinstance(y, pd.Series):
        y = y.values.ravel()
    return X, y

# %%
def run_askl_experiment(openml_id):
    """
    Executa o fluxo completo de avaliação para o auto-sklearn em um dataset.
    """
    print(f"--- Processando Dataset ID: {openml_id} com auto-sklearn ---")
    
    # Orçamento de tempo em segundos. Use 3600 para os resultados finais.
    AUTOML_TIME_BUDGET = 3600  # 10 minutos para um teste rápido

    # 1. Carregamento e pré-processamento
    X_df, y_orig = carregar_base_openml(openml_id)
    
    X_train_df, X_test_df, y_train_orig, y_test_orig = train_test_split(
        X_df, y_orig, test_size=0.3, random_state=SEED, stratify=(y_orig if len(np.unique(y_orig)) > 1 else None)
    )

    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train_orig)
    y_test_enc = le.transform(y_test_orig)

    # Imputação de NaNs numéricos
    num_cols = X_train_df.select_dtypes(include=np.number).columns
    if len(num_cols) > 0 and X_train_df[num_cols].isnull().sum().sum() > 0:
        imp = SimpleImputer(strategy='median')
        X_train_df.loc[:, num_cols] = imp.fit_transform(X_train_df[num_cols])
        X_test_df.loc[:, num_cols] = imp.transform(X_test_df[num_cols])

    # Imputação de NaNs categóricos (convertendo para string)
    cat_cols = X_train_df.select_dtypes(include=['category', 'object']).columns
    if len(cat_cols) > 0:
        for col in cat_cols:
            X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
            X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
            
    # 2. Treinamento com auto-sklearn
    t0_total = time.time()

    automl = AutoSklearn2Classifier(
        time_left_for_this_task=AUTOML_TIME_BUDGET,
        n_jobs=-1,                
        seed=SEED,
        memory_limit=None
    )
    
    # O auto-sklearn lida bem com DataFrames pré-processados
    automl.fit(X_train_df, y_train_enc)
    
    # 3. Predição e Métricas
    y_proba = automl.predict_proba(X_test_df)
    y_pred = automl.predict(X_test_df)
    total_time = time.time() - t0_total

    n_classes = len(le.classes_)
    if n_classes == 2:
        auc_ovo = roc_auc_score(y_test_enc, y_proba[:, 1])
    else:
        auc_ovo = roc_auc_score(y_test_enc, y_proba, multi_class='ovo')

    acc = accuracy_score(y_test_enc, y_pred)
    ce = log_loss(y_test_enc, y_proba, labels=range(n_classes))
    
    # Extrai o melhor score de validação cruzada dos resultados internos
    best_score_cv = np.max(automl.cv_results_['mean_test_score'])


    print(f"Resultados para {openml_id}: AUC={auc_ovo:.4f}, ACC={acc:.4f}, Time={total_time:.2f}s")
    
    return {
        'openml_id': openml_id, 'modelo': 'autosklearn', 'total_time_sec': total_time,
        'mean_auc_ovo': auc_ovo, 'mean_accuracy': acc, 'mean_cross_entropy': ce,
        'best_model_info': 'Ensemble', # O melhor modelo é um ensemble complexo
        'best_score_cv': best_score_cv
    }

# %%
logging.getLogger("autosklearn").setLevel(logging.INFO)
MACHINE_ID = 3
TOTAL_MACHINES = 4

cc18_ids = [
    11, 15, 18, 23, 29, 31, 37, 50, 54, 188,
    307, 458, 469, 1049, 1050, 1063, 1068, 1462, 1464, 1468,
    1480, 1494, 1501, 1510, 6332, 23381, 40966, 40975, 40982, 40994
]

chunk_size = math.ceil(len(cc18_ids) / TOTAL_MACHINES)
start_index = (MACHINE_ID - 1) * chunk_size
end_index = start_index + chunk_size
ids_to_process = cc18_ids[start_index:end_index]

print(f"--- MÁQUINA {MACHINE_ID}/{TOTAL_MACHINES} ---")
print(f"Processando os seguintes datasets: {ids_to_process}")
    
todos_resultados_askl = []

for oid in ids_to_process:
    try:
        res = run_askl_experiment(oid)
        todos_resultados_askl.append(res)
    except Exception as e:
        print(f"!!!!!! ERRO AO PROCESSAR O DATASET {oid}: {e} !!!!!!")
        import traceback
        traceback.print_exc()
        continue

if todos_resultados_askl:
    df_askl_results = pd.DataFrame(todos_resultados_askl)
    print("\n\n--- RESULTADOS FINAIS DO AUTO-SKLEARN ---")
    print(df_askl_results)
    df_askl_results.to_csv("resultados_autosklearn.csv", index=False)
    print("\nArquivo 'resultados_autosklearn.csv' salvo com sucesso!")
else:
    print("\nNenhuma tarefa foi concluída com sucesso.")
# Out:
# --- MÁQUINA 3/4 ---
# Processando os seguintes datasets: [1068, 1462, 1464, 1468, 1480, 1494, 1501, 1510]
# --- Processando Dataset ID: 1068 com auto-sklearn ---
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/sklearn/utils/fixes.py:28: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version  # type: ignore
# [WARNING] [2025-06-15 07:44:28,408:Client-AutoML(42):8cf41446-49bc-11f0-bc81-42010a9e0008] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/conda/envs/askl_env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/pynisher/limit_function_call.py", line 133, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/ensemble_building/builder.py", line 461, in main
#     requires_update = self.requires_loss_update(runs)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/ensemble_building/builder.py", line 666, in requires_loss_update
#     for run in sorted(runs, key=lambda run: run.recorded_mtimes["ensemble"]):
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/ensemble_building/builder.py", line 666, in <lambda>
#     for run in sorted(runs, key=lambda run: run.recorded_mtimes["ensemble"]):
# KeyError: 'ensemble'
# [ERROR] [2025-06-15 08:12:28,371:Client-EnsembleBuilder] Error getting loss `accuracy` for Run(id=(42, 880, 6.25), losses={}):[Errno 2] No such file or directory: '/var/tmp/auto-sklearn_tmp_8cf3fa23-49bc-11f0-bc81-42010a9e0008/.auto-sklearn/runs/42_880_6.25/predictions_ensemble_42_880_6.25.npy'Traceback (most recent call last):
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/ensemble_building/builder.py", line 1076, in loss
#     predictions = run.predictions(kind, precision=self.precision)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/ensemble_building/run.py", line 130, in predictions
#     with path.open("rb") as f:
#   File "/opt/conda/envs/askl_env/lib/python3.9/pathlib.py", line 1180, in open
#     return io.open(self, mode, buffering, encoding, errors, newline,
#   File "/opt/conda/envs/askl_env/lib/python3.9/pathlib.py", line 1038, in _opener
#     return self._accessor.open(self, flags, mode)
# FileNotFoundError: [Errno 2] No such file or directory: '/var/tmp/auto-sklearn_tmp_8cf3fa23-49bc-11f0-bc81-42010a9e0008/.auto-sklearn/runs/42_880_6.25/predictions_ensemble_42_880_6.25.npy'
# Process pynisher function call:
# Traceback (most recent call last):
#   File "/opt/conda/envs/askl_env/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/pynisher/limit_function_call.py", line 133, in subprocess_func
#     return_value = ((func(*args, **kwargs), 0))
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/ensemble_building/builder.py", line 461, in main
#     requires_update = self.requires_loss_update(runs)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/ensemble_building/builder.py", line 666, in requires_loss_update
#     for run in sorted(runs, key=lambda run: run.recorded_mtimes["ensemble"]):
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/ensemble_building/builder.py", line 666, in <lambda>
#     for run in sorted(runs, key=lambda run: run.recorded_mtimes["ensemble"]):
# KeyError: 'ensemble'
# Resultados para 1068: AUC=0.8761, ACC=0.9429, Time=3613.14s
# --- Processando Dataset ID: 1462 com auto-sklearn ---
# [WARNING] [2025-06-15 08:44:37,543:Client-AutoML(42):f6a837b6-49c4-11f0-bc81-42010a9e0008] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [WARNING] [2025-06-15 08:44:39,636:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2025-06-15 08:45:09,373:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:09,378:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:11,664:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:11,668:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:13,703:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:13,709:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:13,793:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:13,801:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:13,900:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:13,904:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:14,048:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:14,051:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:17,185:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:17,195:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:18,969:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:18,973:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:20,841:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:20,849:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:20,927:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:20,931:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:23,157:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:23,159:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:23,281:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:23,286:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:23,402:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:23,405:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:25,690:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:25,698:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:25,802:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:25,812:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:25,943:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:25,949:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:28,689:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:30,642:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:30,750:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:33,458:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:33,570:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:33,689:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:33,845:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:33,962:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:36,197:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:36,345:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:36,459:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:36,580:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:39,268:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:41,768:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:41,847:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:44,452:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:46,501:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:46,599:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:48,852:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:50,954:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:54,000:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:54,063:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:54,195:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:54,294:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:56,846:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:45:59,310:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:01,144:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:01,224:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:03,840:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:06,357:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:06,440:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:06,542:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:09,909:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:12,168:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:12,306:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:12,422:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:12,542:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:12,701:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:12,834:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:16,098:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:16,311:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:16,408:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:16,605:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:19,803:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:22,244:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:22,312:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:24,691:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:24,779:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:24,937:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:25,064:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:27,787:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:27,884:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:30,009:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:30,192:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:33,249:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:33,370:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:33,451:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:33,580:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:33,747:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:33,908:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:37,241:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:37,391:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:37,538:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:39,832:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:39,914:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:42,690:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:42,791:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:42,927:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:45,741:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:45,809:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:46,345:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:48,579:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:48,829:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:48,945:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:51,067:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:53,184:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:55,563:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:57,952:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:58,156:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:46:58,349:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:01,670:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:04,310:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:04,429:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:06,670:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:06,821:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:09,233:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:11,737:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:14,612:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:14,759:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:17,431:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:17,548:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:19,890:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:22,284:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:25,047:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:25,132:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:27,250:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:27,353:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:27,477:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:30,770:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:33,354:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:36,097:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:38,917:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:41,467:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:41,581:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:41,704:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:41,879:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:42,052:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:45,169:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:45,479:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:48,470:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:51,254:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:53,389:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:53,522:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:53,630:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:56,496:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:56,582:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:58,911:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:59,028:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:47:59,180:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:01,689:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:05,090:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:07,374:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:07,490:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:07,659:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:10,185:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:10,588:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:13,305:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:13,444:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:13,701:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:13,875:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:14,018:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:17,250:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:19,086:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:19,233:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:19,325:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:22,273:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:24,562:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:26,681:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:26,798:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:26,949:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:29,191:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:29,461:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:31,389:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:34,319:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:34,457:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:37,053:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:40,163:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:40,258:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:40,354:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:40,520:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:40,717:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:44,152:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:44,239:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:44,418:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:47,382:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:49,691:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:49,822:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:50,045:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:50,252:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:53,179:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:55,563:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:55,736:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:55,910:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:48:58,890:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:00,960:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:03,288:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:05,533:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:08,196:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:08,298:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:08,420:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:11,191:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:13,518:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:15,882:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:16,900:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:19,235:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:21,459:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:21,611:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:24,277:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:24,427:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:26,824:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:28,871:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:30,914:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:31,053:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:31,257:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:31,522:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:34,358:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:37,350:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:37,479:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:37,621:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:37,799:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:37,933:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:38,149:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:38,346:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:38,614:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:39,378:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:43,420:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:45,583:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:45,782:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:48,462:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:48,587:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:48,781:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:51,052:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:51,331:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:53,883:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:56,465:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:49:58,393:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:00,971:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:01,189:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:04,016:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:04,139:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:04,360:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:07,469:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:09,648:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:12,584:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:12,801:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:12,981:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:15,689:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:15,793:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:18,529:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:21,001:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:21,123:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:21,270:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:23,991:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:26,451:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:28,553:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:31,046:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:33,096:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:33,320:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:35,354:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:35,586:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 08:50:38,943:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# ...
# [WARNING] [2025-06-15 09:42:53,957:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:42:57,391:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:42:57,824:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:42:58,349:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:42:58,886:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:03,453:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:03,914:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:07,352:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:07,790:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:11,381:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:11,846:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:16,944:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:17,416:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:17,916:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:21,677:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:22,130:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:22,660:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:23,157:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:24,587:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:28,769:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:32,242:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:35,545:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:36,004:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:39,780:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:43,008:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:43,449:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:44,039:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:45,038:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:48,656:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:51,959:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:55,176:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:55,613:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:43:56,126:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:00,056:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:00,587:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:04,999:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:08,110:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:08,551:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:12,297:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:15,754:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:18,951:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:19,425:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:24,747:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 09:44:27,906:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# Resultados para 1462: AUC=1.0000, ACC=1.0000, Time=3604.08s
# --- Processando Dataset ID: 1464 com auto-sklearn ---
# [WARNING] [2025-06-15 09:45:03,013:Client-AutoML(42):5b036052-49cd-11f0-bc81-42010a9e0008] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [WARNING] [2025-06-15 09:45:07,607:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 09:45:08,452:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 09:45:08,661:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 09:45:10,027:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 09:45:10,639:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# Resultados para 1464: AUC=0.7703, ACC=0.8089, Time=3625.83s
# --- Processando Dataset ID: 1468 com auto-sklearn ---
# [WARNING] [2025-06-15 10:45:10,367:Client-AutoML(42):cc59cd69-49d5-11f0-bc81-42010a9e0008] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [WARNING] [2025-06-15 10:45:12,973:Client-EnsembleBuilder] No runs were available to build an ensemble from
# Resultados para 1468: AUC=0.9956, ACC=0.9506, Time=3616.11s
# --- Processando Dataset ID: 1480 com auto-sklearn ---
# /var/tmp/ipykernel_244865/1891648276.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_244865/1891648276.py:32: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_244865/1891648276.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_244865/1891648276.py:33: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column V2 has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# [WARNING] [2025-06-15 11:45:30,730:Client-AutoML(42):37ce3b55-49de-11f0-bc81-42010a9e0008] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [ERROR] [2025-06-15 11:45:30,843:Client-AutoML(42):37ce3b55-49de-11f0-bc81-42010a9e0008] list index out of range
# Traceback (most recent call last):
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 899, in fit
#     ) = _proc_smac.run_smbo()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/smbo.py", line 552, in run_smbo
#     smac.optimize()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/facade/smac_ac_facade.py", line 720, in optimize
#     incumbent = self.solver.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 211, in run
#     self.start()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 174, in start
#     self.initial_design_configs = self.initial_design.select_configurations()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/initial_design/initial_design.py", line 105, in select_configurations
#     incumbent=self.configs[0])
# IndexError: list index out of range
# !!!!!! ERRO AO PROCESSAR O DATASET 1480: list index out of range !!!!!!
# --- Processando Dataset ID: 1494 com auto-sklearn ---
# Traceback (most recent call last):
#   File "/var/tmp/ipykernel_244865/2714729571.py", line 23, in <module>
#     res = run_askl_experiment(oid)
#   File "/var/tmp/ipykernel_244865/1891648276.py", line 46, in run_askl_experiment
#     automl.fit(X_train_df, y_train_enc)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/experimental/askl2.py", line 540, in fit
#     return super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/estimators.py", line 1448, in fit
#     super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/estimators.py", line 540, in fit
#     self.automl_.fit(load_models=self.load_models, **kwargs)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 2304, in fit
#     return super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 962, in fit
#     raise e
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 899, in fit
#     ) = _proc_smac.run_smbo()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/smbo.py", line 552, in run_smbo
#     smac.optimize()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/facade/smac_ac_facade.py", line 720, in optimize
#     incumbent = self.solver.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 211, in run
#     self.start()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 174, in start
#     self.initial_design_configs = self.initial_design.select_configurations()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/initial_design/initial_design.py", line 105, in select_configurations
#     incumbent=self.configs[0])
# IndexError: list index out of range
# [WARNING] [2025-06-15 11:45:49,279:Client-AutoML(42):410106fe-49de-11f0-bc81-42010a9e0008] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# Resultados para 1494: AUC=0.9373, ACC=0.8833, Time=3629.39s
# --- Processando Dataset ID: 1501 com auto-sklearn ---
# [WARNING] [2025-06-15 12:46:08,165:Client-AutoML(42):b4837e24-49e6-11f0-bc81-42010a9e0008] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# Resultados para 1501: AUC=0.9965, ACC=0.9289, Time=3636.58s
# --- Processando Dataset ID: 1510 com auto-sklearn ---
# [WARNING] [2025-06-15 13:46:47,989:Client-AutoML(42):2caa2e27-49ef-11f0-bc81-42010a9e0008] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# Resultados para 1510: AUC=0.9988, ACC=0.9766, Time=3612.59s
#
#
# --- RESULTADOS FINAIS DO AUTO-SKLEARN ---
#    openml_id       modelo  total_time_sec  mean_auc_ovo  mean_accuracy  \
# 0       1068  autosklearn     3613.142015      0.876087       0.942943
# 1       1462  autosklearn     3604.084644      1.000000       1.000000
# 2       1464  autosklearn     3625.830725      0.770251       0.808889
# 3       1468  autosklearn     3616.107053      0.995595       0.950617
# 4       1494  autosklearn     3629.394815      0.937294       0.883281
# 5       1501  autosklearn     3636.582160      0.996484       0.928870
# 6       1510  autosklearn     3612.588383      0.998832       0.976608
#
#    mean_cross_entropy best_model_info  best_score_cv
# 0            0.175088        Ensemble       0.944588
# 1            0.001782        Ensemble       1.000000
# 2            0.463457        Ensemble       0.806883
# 3            0.546844        Ensemble       0.961640
# 4            0.301989        Ensemble       0.894309
# 5            0.265219        Ensemble       0.947085
# 6            0.128330        Ensemble       0.977387
#
# Arquivo 'resultados_autosklearn.csv' salvo com sucesso!
