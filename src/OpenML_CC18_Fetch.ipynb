# %% [markdown]
# # Preprocessing CC18 30 Menores Datasets
# Este notebook seleciona os 30 menores datasets do benchmark OpenML-CC18, faz pré-processamento (imputação, encoding, normalização) e split 70/30, salvando os resultados em arquivos .npz e .joblib.

# %%
import openml
import os
import joblib
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
from sklearn.model_selection import train_test_split

# Caso possua uma API key:
# openml.config.apikey = 'SUA_CHAVE_AQUI'

# %%
# Obter o benchmark suite CC18
benchmark_suite = openml.study.get_suite(suite_id='OpenML-CC18')
dataset_ids = benchmark_suite.data

# Listar metadados dos datasets
dlist = openml.datasets.list_datasets(data_id=dataset_ids, output_format='dataframe')
# Ordenar por número de instâncias
dlist_sorted_1 = dlist.sort_values(by='status')
dlist_sorted = dlist_sorted_1.sort_values(by='NumberOfInstances')
# Selecionar 30 menores
smallest_30 = dlist_sorted.head(30)
smallest_30
# Out:
#          did                              name  version uploader  status  \
# 23381  23381                     dresses-sales        2       64  active
# 1063    1063                               kc2        1        2  active
# 40994  40994  climate-model-simulation-crashes        4     4265  active
# 6332    6332                    cylinder-bands        2        2  active
# 1510    1510                              wdbc        1       64  active
# 1480    1480                              ilpd        1       64  active
# 11        11                     balance-scale        1        1  active
# 29        29                   credit-approval        1        1  active
# 15        15                          breast-w        1        1  active
# 188      188                        eucalyptus        1        1  active
# 1464    1464  blood-transfusion-service-center        1       64  active
# 37        37                          diabetes        1        1  active
# 469      469                  analcatdata_dmft        1        2  active
# 458      458            analcatdata_authorship        1        2  active
# 54        54                           vehicle        1        1  active
# 50        50                       tic-tac-toe        1        1  active
# 307      307                             vowel        2        2  active
# 31        31                          credit-g        1        1  active
# 1494    1494                       qsar-biodeg        1       64  active
# 1468    1468                            cnae-9        1       64  active
# 40966  40966                       MiceProtein        4        2  active
# 1068    1068                               pc1        1        2  active
# 1462    1462           banknote-authentication        1       64  active
# 1049    1049                               pc4        1        2  active
# 23        23                               cmc        1        1  active
# 1050    1050                               pc3        1        2  active
# 1501    1501                           semeion        1       64  active
# 40975  40975                               car        3     4265  active
# 40982  40982                steel-plates-fault        3     4265  active
# 16        16                    mfeat-karhunen        1        1  active
#
#       format  MajorityClassSize  MaxNominalAttDistinctValues  \
# 23381   ARFF              290.0                         24.0
# 1063    ARFF              415.0                          2.0
# 40994   ARFF              494.0                          2.0
# 6332    ARFF              312.0                         71.0
# 1510    ARFF              357.0                          2.0
# 1480    ARFF              416.0                          2.0
# 11      ARFF              288.0                          3.0
# 29      ARFF              383.0                         14.0
# 15      ARFF              458.0                          2.0
# 188     ARFF              214.0                         27.0
# 1464    ARFF              570.0                          2.0
# 37      ARFF              500.0                          2.0
# 469     ARFF              155.0                          9.0
# 458     ARFF              317.0                          4.0
# 54      ARFF              218.0                          4.0
# 50      ARFF              626.0                          3.0
# 307     ARFF               90.0                         15.0
# 31      ARFF              700.0                         10.0
# 1494    ARFF              699.0                          2.0
# 1468    ARFF              120.0                          9.0
# 40966   ARFF              150.0                          8.0
# 1068    ARFF             1032.0                          2.0
# 1462    ARFF              762.0                          2.0
# 1049    ARFF             1280.0                          2.0
# 23      ARFF              629.0                          4.0
# 1050    ARFF             1403.0                          2.0
# 1501    ARFF              162.0                         10.0
# 40975   ARFF             1210.0                          4.0
# 40982   ARFF              673.0                          7.0
# 16      ARFF              200.0                         10.0
#
#        MinorityClassSize  NumberOfClasses  NumberOfFeatures  \
# 23381              210.0              2.0              13.0
# 1063               107.0              2.0              22.0
# 40994               46.0              2.0              21.0
# 6332               228.0              2.0              40.0
# 1510               212.0              2.0              31.0
# 1480               167.0              2.0              11.0
# 11                  49.0              3.0               5.0
# 29                 307.0              2.0              16.0
# 15                 241.0              2.0              10.0
# 188                105.0              5.0              20.0
# 1464               178.0              2.0               5.0
# 37                 268.0              2.0               9.0
# 469                123.0              6.0               5.0
# 458                 55.0              4.0              71.0
# 54                 199.0              4.0              19.0
# 50                 332.0              2.0              10.0
# 307                 90.0             11.0              13.0
# 31                 300.0              2.0              21.0
# 1494               356.0              2.0              42.0
# 1468               120.0              9.0             857.0
# 40966              105.0              8.0              82.0
# 1068                77.0              2.0              22.0
# 1462               610.0              2.0               5.0
# 1049               178.0              2.0              38.0
# 23                 333.0              3.0              10.0
# 1050               160.0              2.0              38.0
# 1501               155.0             10.0             257.0
# 40975               65.0              4.0               7.0
# 40982               55.0              7.0              28.0
# 16                 200.0             10.0              65.0
#
#        NumberOfInstances  NumberOfInstancesWithMissingValues  \
# 23381              500.0                               401.0
# 1063               522.0                                 0.0
# 40994              540.0                                 0.0
# 6332               540.0                               263.0
# 1510               569.0                                 0.0
# 1480               583.0                                 0.0
# 11                 625.0                                 0.0
# 29                 690.0                                37.0
# 15                 699.0                                16.0
# 188                736.0                                95.0
# 1464               748.0                                 0.0
# 37                 768.0                                 0.0
# 469                797.0                                 0.0
# 458                841.0                                 0.0
# 54                 846.0                                 0.0
# 50                 958.0                                 0.0
# 307                990.0                                 0.0
# 31                1000.0                                 0.0
# 1494              1055.0                                 0.0
# 1468              1080.0                                 0.0
# 40966             1080.0                               528.0
# 1068              1109.0                                 0.0
# 1462              1372.0                                 0.0
# 1049              1458.0                                 0.0
# 23                1473.0                                 0.0
# 1050              1563.0                                 0.0
# 1501              1593.0                                 0.0
# 40975             1728.0                                 0.0
# 40982             1941.0                                 0.0
# 16                2000.0                                 0.0
#
#        NumberOfMissingValues  NumberOfNumericFeatures  \
# 23381                  835.0                      1.0
# 1063                     0.0                     21.0
# 40994                    0.0                     20.0
# 6332                   999.0                     18.0
# 1510                     0.0                     30.0
# 1480                     0.0                      9.0
# 11                       0.0                      4.0
# 29                      67.0                      6.0
# 15                      16.0                      9.0
# 188                    448.0                     14.0
# 1464                     0.0                      4.0
# 37                       0.0                      8.0
# 469                      0.0                      0.0
# 458                      0.0                     70.0
# 54                       0.0                     18.0
# 50                       0.0                      0.0
# 307                      0.0                     10.0
# 31                       0.0                      7.0
# 1494                     0.0                     41.0
# 1468                     0.0                    856.0
# 40966                 1396.0                     77.0
# 1068                     0.0                     21.0
# 1462                     0.0                      4.0
# 1049                     0.0                     37.0
# 23                       0.0                      2.0
# 1050                     0.0                     37.0
# 1501                     0.0                    256.0
# 40975                    0.0                      0.0
# 40982                    0.0                     27.0
# 16                       0.0                     64.0
#
#        NumberOfSymbolicFeatures
# 23381                      12.0
# 1063                        1.0
# 40994                       1.0
# 6332                       22.0
# 1510                        1.0
# 1480                        2.0
# 11                          1.0
# 29                         10.0
# 15                          1.0
# 188                         6.0
# 1464                        1.0
# 37                          1.0
# 469                         5.0
# 458                         1.0
# 54                          1.0
# 50                         10.0
# 307                         3.0
# 31                         14.0
# 1494                        1.0
# 1468                        1.0
# 40966                       5.0
# 1068                        1.0
# 1462                        1.0
# 1049                        1.0
# 23                          8.0
# 1050                        1.0
# 1501                        1.0
# 40975                       7.0
# 40982                       1.0
# 16                          1.0

# %%
OUTPUT_DIR = "raw_cc18_30"
os.makedirs(OUTPUT_DIR, exist_ok=True)

for idx, row in smallest_30.iterrows():
    data_id = int(row["did"])
    name = row["name"].replace(" ", "_")
    csv_filename = f"{data_id}_{name}.csv"
    csv_path = os.path.join(OUTPUT_DIR, csv_filename)

    try:
        # a) Baixar o dataset completo via OpenML
        dataset = openml.datasets.get_dataset(data_id)
        X_df, y_series, _, _ = dataset.get_data(
            dataset_format="dataframe",
            target=dataset.default_target_attribute
        )

        # b) Concatena features e target num único DataFrame
        df = X_df.copy()
        df["target"] = y_series

        # c) Salvar em CSV
        df.to_csv(csv_path, index=False)
        print(f"→ Salvou: {csv_filename}  ({X_df.shape[0]} instâncias, {X_df.shape[1]} features + 1 alvo)")

    except Exception as e:
        print(f"[PULO] Falha ao baixar data_id={data_id} ({name}): {e}")
# Out:
# → Salvou: 23381_dresses-sales.csv  (500 instâncias, 12 features + 1 alvo)
# → Salvou: 1063_kc2.csv  (522 instâncias, 21 features + 1 alvo)
# → Salvou: 40994_climate-model-simulation-crashes.csv  (540 instâncias, 18 features + 1 alvo)
# → Salvou: 6332_cylinder-bands.csv  (540 instâncias, 37 features + 1 alvo)
# → Salvou: 1510_wdbc.csv  (569 instâncias, 30 features + 1 alvo)
# → Salvou: 1480_ilpd.csv  (583 instâncias, 10 features + 1 alvo)
# → Salvou: 11_balance-scale.csv  (625 instâncias, 4 features + 1 alvo)
# → Salvou: 29_credit-approval.csv  (690 instâncias, 15 features + 1 alvo)
# → Salvou: 15_breast-w.csv  (699 instâncias, 9 features + 1 alvo)
# → Salvou: 188_eucalyptus.csv  (736 instâncias, 19 features + 1 alvo)
# → Salvou: 1464_blood-transfusion-service-center.csv  (748 instâncias, 4 features + 1 alvo)
# → Salvou: 37_diabetes.csv  (768 instâncias, 8 features + 1 alvo)
# → Salvou: 469_analcatdata_dmft.csv  (797 instâncias, 4 features + 1 alvo)
# → Salvou: 458_analcatdata_authorship.csv  (841 instâncias, 70 features + 1 alvo)
# → Salvou: 54_vehicle.csv  (846 instâncias, 18 features + 1 alvo)
# → Salvou: 50_tic-tac-toe.csv  (958 instâncias, 9 features + 1 alvo)
# → Salvou: 307_vowel.csv  (990 instâncias, 12 features + 1 alvo)
# → Salvou: 31_credit-g.csv  (1000 instâncias, 20 features + 1 alvo)
# → Salvou: 1494_qsar-biodeg.csv  (1055 instâncias, 41 features + 1 alvo)
# → Salvou: 1468_cnae-9.csv  (1080 instâncias, 856 features + 1 alvo)
# → Salvou: 40966_MiceProtein.csv  (1080 instâncias, 77 features + 1 alvo)
# → Salvou: 1068_pc1.csv  (1109 instâncias, 21 features + 1 alvo)
# → Salvou: 1462_banknote-authentication.csv  (1372 instâncias, 4 features + 1 alvo)
# → Salvou: 1049_pc4.csv  (1458 instâncias, 37 features + 1 alvo)
# → Salvou: 23_cmc.csv  (1473 instâncias, 9 features + 1 alvo)
# → Salvou: 1050_pc3.csv  (1563 instâncias, 37 features + 1 alvo)
# → Salvou: 1501_semeion.csv  (1593 instâncias, 256 features + 1 alvo)
# → Salvou: 40975_car.csv  (1728 instâncias, 6 features + 1 alvo)
# → Salvou: 40982_steel-plates-fault.csv  (1941 instâncias, 27 features + 1 alvo)
# → Salvou: 16_mfeat-karhunen.csv  (2000 instâncias, 64 features + 1 alvo)
