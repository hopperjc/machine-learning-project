# %%
import time
import pandas as pd
import numpy as np
import openml
import warnings
import math
import logging

# Imports do scikit-learn e auto-sklearn
from autosklearn.experimental.askl2 import AutoSklearn2Classifier

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score, accuracy_score, log_loss
# Out:
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/sklearn/utils/fixes.py:28: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version  # type: ignore

# %%
# Configurações
SEED = 42
warnings.filterwarnings("ignore", category=FutureWarning)

def carregar_base_openml(openml_id):
    """Carrega um dataset do OpenML e prepara os tipos de dados."""
    dataset = openml.datasets.get_dataset(openml_id, download_data=True, download_qualities=True, download_features_meta_data=True)
    X, y, _, _ = dataset.get_data(dataset_format="dataframe", target=dataset.default_target_attribute)
    if isinstance(y, pd.Series):
        y = y.values.ravel()
    return X, y

# %%
def run_askl_experiment(openml_id):
    """
    Executa o fluxo completo de avaliação para o auto-sklearn em um dataset.
    """
    print(f"--- Processando Dataset ID: {openml_id} com auto-sklearn ---")
    
    # Orçamento de tempo em segundos. Use 3600 para os resultados finais.
    AUTOML_TIME_BUDGET = 3600  # 10 minutos para um teste rápido

    # 1. Carregamento e pré-processamento
    X_df, y_orig = carregar_base_openml(openml_id)
    
    X_train_df, X_test_df, y_train_orig, y_test_orig = train_test_split(
        X_df, y_orig, test_size=0.3, random_state=SEED, stratify=(y_orig if len(np.unique(y_orig)) > 1 else None)
    )

    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train_orig)
    y_test_enc = le.transform(y_test_orig)

    # Imputação de NaNs numéricos
    num_cols = X_train_df.select_dtypes(include=np.number).columns
    if len(num_cols) > 0 and X_train_df[num_cols].isnull().sum().sum() > 0:
        imp = SimpleImputer(strategy='median')
        X_train_df.loc[:, num_cols] = imp.fit_transform(X_train_df[num_cols])
        X_test_df.loc[:, num_cols] = imp.transform(X_test_df[num_cols])

    # Imputação de NaNs categóricos (convertendo para string)
    cat_cols = X_train_df.select_dtypes(include=['category', 'object']).columns
    if len(cat_cols) > 0:
        for col in cat_cols:
            X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
            X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
            
    # 2. Treinamento com auto-sklearn
    t0_total = time.time()

    automl = AutoSklearn2Classifier(
        time_left_for_this_task=AUTOML_TIME_BUDGET,
        n_jobs=-1,                
        seed=SEED,
        memory_limit=None
    )
    
    # O auto-sklearn lida bem com DataFrames pré-processados
    automl.fit(X_train_df, y_train_enc)
    
    # 3. Predição e Métricas
    y_proba = automl.predict_proba(X_test_df)
    y_pred = automl.predict(X_test_df)
    total_time = time.time() - t0_total

    n_classes = len(le.classes_)
    if n_classes == 2:
        auc_ovo = roc_auc_score(y_test_enc, y_proba[:, 1])
    else:
        auc_ovo = roc_auc_score(y_test_enc, y_proba, multi_class='ovo')

    acc = accuracy_score(y_test_enc, y_pred)
    ce = log_loss(y_test_enc, y_proba, labels=range(n_classes))
    
    # Extrai o melhor score de validação cruzada dos resultados internos
    best_score_cv = np.max(automl.cv_results_['mean_test_score'])


    print(f"Resultados para {openml_id}: AUC={auc_ovo:.4f}, ACC={acc:.4f}, Time={total_time:.2f}s")
    
    return {
        'openml_id': openml_id, 'modelo': 'autosklearn', 'total_time_sec': total_time,
        'mean_auc_ovo': auc_ovo, 'mean_accuracy': acc, 'mean_cross_entropy': ce,
        'best_model_info': 'Ensemble', # O melhor modelo é um ensemble complexo
        'best_score_cv': best_score_cv
    }

# %%
logging.getLogger("autosklearn").setLevel(logging.INFO)
MACHINE_ID = 2
TOTAL_MACHINES = 4

cc18_ids = [
    11, 15, 18, 23, 29, 31, 37, 50, 54, 188,
    307, 458, 469, 1049, 1050, 1063, 1068, 1462, 1464, 1468,
    1480, 1494, 1501, 1510, 6332, 23381, 40966, 40975, 40982, 40994
]

chunk_size = math.ceil(len(cc18_ids) / TOTAL_MACHINES)
start_index = (MACHINE_ID - 1) * chunk_size
end_index = start_index + chunk_size
ids_to_process = cc18_ids[start_index:end_index]

print(f"--- MÁQUINA {MACHINE_ID}/{TOTAL_MACHINES} ---")
print(f"Processando os seguintes datasets: {ids_to_process}")
    
todos_resultados_askl = []

for oid in ids_to_process:
    try:
        res = run_askl_experiment(oid)
        todos_resultados_askl.append(res)
    except Exception as e:
        print(f"!!!!!! ERRO AO PROCESSAR O DATASET {oid}: {e} !!!!!!")
        import traceback
        traceback.print_exc()
        continue

if todos_resultados_askl:
    df_askl_results = pd.DataFrame(todos_resultados_askl)
    print("\n\n--- RESULTADOS FINAIS DO AUTO-SKLEARN ---")
    print(df_askl_results)
    df_askl_results.to_csv("resultados_autosklearn.csv", index=False)
    print("\nArquivo 'resultados_autosklearn.csv' salvo com sucesso!")
else:
    print("\nNenhuma tarefa foi concluída com sucesso.")
# Out:
# --- MÁQUINA 2/4 ---
# Processando os seguintes datasets: [54, 188, 307, 458, 469, 1049, 1050, 1063]
# --- Processando Dataset ID: 54 com auto-sklearn ---
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/sklearn/utils/fixes.py:28: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version  # type: ignore
# [WARNING] [2025-06-15 01:03:52,434:Client-AutoML(42):98fcc312-4984-11f0-b1d0-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# Resultados para 54: AUC=0.9603, ACC=0.8307, Time=3608.16s
# --- Processando Dataset ID: 188 com auto-sklearn ---
# /var/tmp/ipykernel_45520/1891648276.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, num_cols] = imp.fit_transform(X_train_df[num_cols])
# /var/tmp/ipykernel_45520/1891648276.py:25: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, num_cols] = imp.fit_transform(X_train_df[num_cols])
# /var/tmp/ipykernel_45520/1891648276.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, num_cols] = imp.transform(X_test_df[num_cols])
# /var/tmp/ipykernel_45520/1891648276.py:26: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, num_cols] = imp.transform(X_test_df[num_cols])
# /var/tmp/ipykernel_45520/1891648276.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:32: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:33: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Abbrev has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Locality has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Map_Ref has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Latitude has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Sp has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# [WARNING] [2025-06-15 02:04:04,622:Client-AutoML(42):ffe28f0e-498c-11f0-b1d0-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [ERROR] [2025-06-15 02:04:04,713:Client-AutoML(42):ffe28f0e-498c-11f0-b1d0-42010a800006] list index out of range
# Traceback (most recent call last):
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 899, in fit
#     ) = _proc_smac.run_smbo()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/smbo.py", line 552, in run_smbo
#     smac.optimize()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/facade/smac_ac_facade.py", line 720, in optimize
#     incumbent = self.solver.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 211, in run
#     self.start()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 174, in start
#     self.initial_design_configs = self.initial_design.select_configurations()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/initial_design/initial_design.py", line 105, in select_configurations
#     incumbent=self.configs[0])
# IndexError: list index out of range
# !!!!!! ERRO AO PROCESSAR O DATASET 188: list index out of range !!!!!!
# --- Processando Dataset ID: 307 com auto-sklearn ---
# Traceback (most recent call last):
#   File "/var/tmp/ipykernel_45520/1124852268.py", line 23, in <module>
#     res = run_askl_experiment(oid)
#   File "/var/tmp/ipykernel_45520/1891648276.py", line 46, in run_askl_experiment
#     automl.fit(X_train_df, y_train_enc)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/experimental/askl2.py", line 540, in fit
#     return super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/estimators.py", line 1448, in fit
#     super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/estimators.py", line 540, in fit
#     self.automl_.fit(load_models=self.load_models, **kwargs)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 2304, in fit
#     return super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 962, in fit
#     raise e
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 899, in fit
#     ) = _proc_smac.run_smbo()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/smbo.py", line 552, in run_smbo
#     smac.optimize()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/facade/smac_ac_facade.py", line 720, in optimize
#     incumbent = self.solver.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 211, in run
#     self.start()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 174, in start
#     self.initial_design_configs = self.initial_design.select_configurations()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/initial_design/initial_design.py", line 105, in select_configurations
#     incumbent=self.configs[0])
# IndexError: list index out of range
# /var/tmp/ipykernel_45520/1891648276.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:32: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:33: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Speaker_Number has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Sex has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# [WARNING] [2025-06-15 02:04:16,715:Client-AutoML(42):073571fd-498d-11f0-b1d0-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [ERROR] [2025-06-15 02:04:16,805:Client-AutoML(42):073571fd-498d-11f0-b1d0-42010a800006] list index out of range
# Traceback (most recent call last):
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 899, in fit
#     ) = _proc_smac.run_smbo()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/smbo.py", line 552, in run_smbo
#     smac.optimize()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/facade/smac_ac_facade.py", line 720, in optimize
#     incumbent = self.solver.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 211, in run
#     self.start()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 174, in start
#     self.initial_design_configs = self.initial_design.select_configurations()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/initial_design/initial_design.py", line 105, in select_configurations
#     incumbent=self.configs[0])
# IndexError: list index out of range
# !!!!!! ERRO AO PROCESSAR O DATASET 307: list index out of range !!!!!!
# --- Processando Dataset ID: 458 com auto-sklearn ---
# Traceback (most recent call last):
#   File "/var/tmp/ipykernel_45520/1124852268.py", line 23, in <module>
#     res = run_askl_experiment(oid)
#   File "/var/tmp/ipykernel_45520/1891648276.py", line 46, in run_askl_experiment
#     automl.fit(X_train_df, y_train_enc)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/experimental/askl2.py", line 540, in fit
#     return super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/estimators.py", line 1448, in fit
#     super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/estimators.py", line 540, in fit
#     self.automl_.fit(load_models=self.load_models, **kwargs)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 2304, in fit
#     return super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 962, in fit
#     raise e
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 899, in fit
#     ) = _proc_smac.run_smbo()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/smbo.py", line 552, in run_smbo
#     smac.optimize()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/facade/smac_ac_facade.py", line 720, in optimize
#     incumbent = self.solver.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 211, in run
#     self.start()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 174, in start
#     self.initial_design_configs = self.initial_design.select_configurations()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/initial_design/initial_design.py", line 105, in select_configurations
#     incumbent=self.configs[0])
# IndexError: list index out of range
# [WARNING] [2025-06-15 02:04:23,993:Client-AutoML(42):0e749853-498d-11f0-b1d0-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [WARNING] [2025-06-15 02:04:51,276:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:04:52,138:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:04:53,852:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:04:55,919:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:00,367:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:00,368:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:00,439:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:00,440:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:02,042:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:02,058:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:04,441:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:04,445:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:04,727:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:04,729:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:06,157:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:06,159:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:07,714:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:07,717:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:07,844:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:07,846:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:10,906:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:10,908:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:13,767:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:13,774:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:13,777:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:13,917:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:13,927:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:13,929:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,596:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,598:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,599:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,732:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,735:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,738:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,858:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,860:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:16,863:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:19,681:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:19,683:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:19,687:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,280:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,292:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,298:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,404:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,406:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,408:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,494:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,500:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:22,506:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:24,954:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:24,956:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:24,965:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:27,339:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:27,341:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:27,346:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:29,809:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:29,813:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:29,817:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:29,906:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:29,908:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:29,910:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:30,042:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:30,055:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:30,060:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:32,594:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:32,596:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:32,598:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:35,432:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:37,985:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:39,686:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:39,735:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:39,829:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:42,231:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:44,919:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:47,416:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:49,777:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:49,887:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:49,945:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:50,054:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:53,082:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:56,099:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:56,188:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:56,271:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:05:59,969:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:00,085:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:00,170:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:01,001:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:04,736:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:04,816:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:08,101:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:08,226:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:08,325:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:12,034:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:15,364:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:15,467:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:15,565:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:18,726:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:21,480:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:24,296:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:24,400:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:27,200:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:29,932:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:31,940:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:34,231:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:36,865:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:36,971:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:37,065:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:37,216:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:37,404:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:37,594:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:41,120:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:41,221:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:41,321:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:43,868:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:43,976:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:45,128:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:48,189:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:50,150:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:52,026:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:52,185:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:52,304:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:52,468:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:54,932:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:55,072:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:55,201:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:56,148:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:59,025:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:06:59,180:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:02,468:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:02,672:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:05,756:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:05,895:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:06,006:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:08,432:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:08,580:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:08,691:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:09,166:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:12,459:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:12,615:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:15,872:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:18,678:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:18,847:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:21,277:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:23,009:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:23,177:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:23,301:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:23,458:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:26,293:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:28,271:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:30,239:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:32,106:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:32,316:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:32,465:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:35,335:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:37,458:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:37,681:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:40,336:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:40,463:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:42,295:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:42,522:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:45,178:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:46,775:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:46,898:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:49,108:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:50,642:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:50,738:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:50,866:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:52,636:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:54,735:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:54,924:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:07:57,736:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:00,239:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:00,418:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:00,595:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:03,674:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:03,815:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:03,962:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:04,228:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:07,088:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:09,571:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:12,241:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:14,335:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:16,961:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:17,140:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:19,303:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:20,992:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:22,870:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:23,043:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:25,250:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:25,392:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:28,423:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:30,617:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:30,835:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:31,012:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:34,215:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:34,324:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:36,430:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:38,821:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:40,992:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:41,137:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:41,297:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:41,465:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:41,696:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:41,878:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 02:08:42,115:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# ...
# [WARNING] [2025-06-15 03:03:45,847:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:03:46,578:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:03:47,405:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:03:51,458:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:03:54,567:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:03:57,619:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:03:58,337:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:03:59,412:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:04:02,762:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:04:05,453:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:04:06,460:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:04:10,086:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# [WARNING] [2025-06-15 03:04:13,609:smac.runhistory.runhistory2epm.RunHistory2EPM4LogCost] Got cost of smaller/equal to 0. Replace by 0.000010 since we use log cost.
# Resultados para 458: AUC=0.9999, ACC=0.9960, Time=3605.74s
# --- Processando Dataset ID: 469 com auto-sklearn ---
# /var/tmp/ipykernel_45520/1891648276.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:32: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_45520/1891648276.py:33: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column DMFT.Begin has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column DMFT.End has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Gender has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Ethnic has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# [WARNING] [2025-06-15 03:04:35,151:Client-AutoML(42):7528c8be-4995-11f0-b1d0-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [ERROR] [2025-06-15 03:04:35,233:Client-AutoML(42):7528c8be-4995-11f0-b1d0-42010a800006] list index out of range
# Traceback (most recent call last):
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 899, in fit
#     ) = _proc_smac.run_smbo()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/smbo.py", line 552, in run_smbo
#     smac.optimize()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/facade/smac_ac_facade.py", line 720, in optimize
#     incumbent = self.solver.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 211, in run
#     self.start()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 174, in start
#     self.initial_design_configs = self.initial_design.select_configurations()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/initial_design/initial_design.py", line 105, in select_configurations
#     incumbent=self.configs[0])
# IndexError: list index out of range
# !!!!!! ERRO AO PROCESSAR O DATASET 469: list index out of range !!!!!!
# --- Processando Dataset ID: 1049 com auto-sklearn ---
# Traceback (most recent call last):
#   File "/var/tmp/ipykernel_45520/1124852268.py", line 23, in <module>
#     res = run_askl_experiment(oid)
#   File "/var/tmp/ipykernel_45520/1891648276.py", line 46, in run_askl_experiment
#     automl.fit(X_train_df, y_train_enc)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/experimental/askl2.py", line 540, in fit
#     return super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/estimators.py", line 1448, in fit
#     super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/estimators.py", line 540, in fit
#     self.automl_.fit(load_models=self.load_models, **kwargs)
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 2304, in fit
#     return super().fit(
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 962, in fit
#     raise e
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/automl.py", line 899, in fit
#     ) = _proc_smac.run_smbo()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/smbo.py", line 552, in run_smbo
#     smac.optimize()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/facade/smac_ac_facade.py", line 720, in optimize
#     incumbent = self.solver.run()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 211, in run
#     self.start()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/optimizer/smbo.py", line 174, in start
#     self.initial_design_configs = self.initial_design.select_configurations()
#   File "/opt/conda/envs/askl_env/lib/python3.9/site-packages/smac/initial_design/initial_design.py", line 105, in select_configurations
#     incumbent=self.configs[0])
# IndexError: list index out of range
# [WARNING] [2025-06-15 03:04:44,459:Client-AutoML(42):7c7d2e1b-4995-11f0-b1d0-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [WARNING] [2025-06-15 03:04:46,729:Client-EnsembleBuilder] No runs were available to build an ensemble from
# Resultados para 1049: AUC=0.9230, ACC=0.9087, Time=3604.19s
# --- Processando Dataset ID: 1050 com auto-sklearn ---
# [WARNING] [2025-06-15 04:04:53,689:Client-AutoML(42):e2d67656-499d-11f0-b1d0-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [WARNING] [2025-06-15 04:04:55,282:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2025-06-15 04:04:55,465:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2025-06-15 04:04:55,563:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2025-06-15 04:04:56,894:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:04:56,989:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:04:57,785:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:04:58,573:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:04:58,889:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:00,153:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:00,564:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:01,069:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:01,864:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:02,397:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:03,540:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:05,443:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:06,327:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:07,061:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:07,633:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:08,134:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:10,566:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:11,369:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:14,044:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:16,718:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:21,989:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:23,780:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:25,708:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:27,507:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:29,580:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:31,334:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:33,027:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:35,416:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:38,158:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:41,113:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:47,624:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:49,417:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:51,085:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2025-06-15 04:05:53,381:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# Resultados para 1050: AUC=0.8260, ACC=0.8998, Time=3608.26s
# --- Processando Dataset ID: 1063 com auto-sklearn ---
# [WARNING] [2025-06-15 05:05:10,022:Client-AutoML(42):4f01d9b7-49a6-11f0-b1d0-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# Resultados para 1063: AUC=0.7721, ACC=0.8089, Time=3606.11s
#
#
# --- RESULTADOS FINAIS DO AUTO-SKLEARN ---
#    openml_id       modelo  total_time_sec  mean_auc_ovo  mean_accuracy  \
# 0         54  autosklearn     3608.157921      0.960278       0.830709
# 1        458  autosklearn     3605.743413      0.999905       0.996047
# 2       1049  autosklearn     3604.191525      0.922960       0.908676
# 3       1050  autosklearn     3608.262226      0.826010       0.899787
# 4       1063  autosklearn     3606.112460      0.772125       0.808917
#
#    mean_cross_entropy best_model_info  best_score_cv
# 0            0.350651        Ensemble       0.822635
# 1            0.723658        Ensemble       1.000000
# 2            0.250436        Ensemble       0.920588
# 3            0.269360        Ensemble       0.904022
# 4            0.432636        Ensemble       0.865753
#
# Arquivo 'resultados_autosklearn.csv' salvo com sucesso!

# %%
from autosklearn.classification import AutoSklearnClassifier

def run_askl_experiment_optional(openml_id):
    """
    Executa o fluxo completo de avaliação para o auto-sklearn em um dataset.
    """
    print(f"--- Processando Dataset ID: {openml_id} com auto-sklearn ---")
    
    # Orçamento de tempo em segundos. Use 3600 para os resultados finais.
    AUTOML_TIME_BUDGET = 3600  # 10 minutos para um teste rápido

    # 1. Carregamento e pré-processamento
    X_df, y_orig = carregar_base_openml(openml_id)
    
    X_train_df, X_test_df, y_train_orig, y_test_orig = train_test_split(
        X_df, y_orig, test_size=0.3, random_state=SEED, stratify=(y_orig if len(np.unique(y_orig)) > 1 else None)
    )

    le = LabelEncoder()
    y_train_enc = le.fit_transform(y_train_orig)
    y_test_enc = le.transform(y_test_orig)

    # Imputação de NaNs numéricos
    num_cols = X_train_df.select_dtypes(include=np.number).columns
    if len(num_cols) > 0 and X_train_df[num_cols].isnull().sum().sum() > 0:
        imp = SimpleImputer(strategy='median')
        X_train_df.loc[:, num_cols] = imp.fit_transform(X_train_df[num_cols])
        X_test_df.loc[:, num_cols] = imp.transform(X_test_df[num_cols])

    # Imputação de NaNs categóricos (convertendo para string)
    cat_cols = X_train_df.select_dtypes(include=['category', 'object']).columns
    if len(cat_cols) > 0:
        for col in cat_cols:
            X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
            X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
            
    # 2. Treinamento com auto-sklearn
    t0_total = time.time()

    automl = AutoSklearnClassifier(
        time_left_for_this_task=AUTOML_TIME_BUDGET,
        n_jobs=-1,                
        seed=SEED,
        memory_limit=None
        #initial_configurations_via_metalearning=0
    )
    
    # O auto-sklearn lida bem com DataFrames pré-processados
    automl.fit(X_train_df, y_train_enc)
    
    # 3. Predição e Métricas
    y_proba = automl.predict_proba(X_test_df)
    y_pred = automl.predict(X_test_df)
    total_time = time.time() - t0_total

    n_classes = len(le.classes_)
    if n_classes == 2:
        auc_ovo = roc_auc_score(y_test_enc, y_proba[:, 1])
    else:
        auc_ovo = roc_auc_score(y_test_enc, y_proba, multi_class='ovo')

    acc = accuracy_score(y_test_enc, y_pred)
    ce = log_loss(y_test_enc, y_proba, labels=range(n_classes))
    
    # Extrai o melhor score de validação cruzada dos resultados internos
    best_score_cv = np.max(automl.cv_results_['mean_test_score'])


    print(f"Resultados para {openml_id}: AUC={auc_ovo:.4f}, ACC={acc:.4f}, Time={total_time:.2f}s")
    
    return {
        'openml_id': openml_id, 'modelo': 'autosklearn', 'total_time_sec': total_time,
        'mean_auc_ovo': auc_ovo, 'mean_accuracy': acc, 'mean_cross_entropy': ce,
        'best_model_info': 'Ensemble', # O melhor modelo é um ensemble complexo
        'best_score_cv': best_score_cv
    }

# %%
ids_to_process = [188, 307, 469]

print(f"Processando os seguintes datasets: {ids_to_process}")
    
todos_resultados_askl = []

for oid in ids_to_process:
    try:
        res = run_askl_experiment_optional(oid)
        todos_resultados_askl.append(res)
    except Exception as e:
        print(f"!!!!!! ERRO AO PROCESSAR O DATASET {oid}: {e} !!!!!!")
        import traceback
        traceback.print_exc()
        continue

if todos_resultados_askl:
    df_askl_results = pd.DataFrame(todos_resultados_askl)
    print("\n\n--- RESULTADOS FINAIS DO AUTO-SKLEARN ---")
    print(df_askl_results)
    df_askl_results.to_csv("resultados_autosklearn2.csv", index=False)
    print("\nArquivo 'resultados_autosklearn.csv' salvo com sucesso!")
else:
    print("\nNenhuma tarefa foi concluída com sucesso.")
# Out:
# /var/tmp/ipykernel_238250/2533747859.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, num_cols] = imp.fit_transform(X_train_df[num_cols])
# /var/tmp/ipykernel_238250/2533747859.py:27: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, num_cols] = imp.fit_transform(X_train_df[num_cols])
# /var/tmp/ipykernel_238250/2533747859.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, num_cols] = imp.transform(X_test_df[num_cols])
# /var/tmp/ipykernel_238250/2533747859.py:28: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, num_cols] = imp.transform(X_test_df[num_cols])
# /var/tmp/ipykernel_238250/2533747859.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:34: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:35: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# Processando os seguintes datasets: [188, 307, 469]
# --- Processando Dataset ID: 188 com auto-sklearn ---
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/sklearn/utils/fixes.py:28: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version  # type: ignore
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Abbrev has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Locality has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Map_Ref has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Latitude has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Sp has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# [WARNING] [2025-06-15 07:58:10,422:Client-AutoML(42):7846e9d4-49be-11f0-a2aa-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [WARNING] [2025-06-15 07:58:13,200:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2025-06-15 07:58:13,299:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2025-06-15 07:58:13,623:Client-EnsembleBuilder] No runs were available to build an ensemble from
# Resultados para 188: AUC=0.9130, ACC=0.6878, Time=3611.90s
# --- Processando Dataset ID: 307 com auto-sklearn ---
# /var/tmp/ipykernel_238250/2533747859.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:34: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:35: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Speaker_Number has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Sex has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# [WARNING] [2025-06-15 08:58:23,027:Client-AutoML(42):e13a4207-49c6-11f0-a2aa-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# [WARNING] [2025-06-15 08:58:25,373:Client-EnsembleBuilder] No runs were available to build an ensemble from
# Resultados para 307: AUC=0.9918, ACC=0.9394, Time=3603.48s
# --- Processando Dataset ID: 469 com auto-sklearn ---
# /var/tmp/ipykernel_238250/2533747859.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:34: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_train_df.loc[:, col] = X_train_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /var/tmp/ipykernel_238250/2533747859.py:35: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   X_test_df.loc[:, col] = X_test_df[col].astype(str).fillna("__MISSING__")
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column DMFT.Begin has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column DMFT.End has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Gender has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /opt/conda/envs/askl_env/lib/python3.9/site-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Ethnic has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# [WARNING] [2025-06-15 09:58:22,239:Client-AutoML(42):452b1b47-49cf-11f0-a2aa-42010a800006] Capping the per_run_time_limit to 1799.0 to have time for a least 2 models in each process.
# Resultados para 469: AUC=0.5301, ACC=0.1875, Time=3600.28s
#
#
# --- RESULTADOS FINAIS DO AUTO-SKLEARN ---
#    openml_id       modelo  total_time_sec  mean_auc_ovo  mean_accuracy  \
# 0        188  autosklearn     3611.899683      0.912970       0.687783
# 1        307  autosklearn     3603.481673      0.991770       0.939394
# 2        469  autosklearn     3600.283135      0.530075       0.187500
#
#    mean_cross_entropy best_model_info  best_score_cv
# 0            0.797372        Ensemble       0.741176
# 1            0.537557        Ensemble       0.978166
# 2            1.778261        Ensemble       0.239130
#
# Arquivo 'resultados_autosklearn.csv' salvo com sucesso!
